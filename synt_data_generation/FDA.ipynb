# %%
import numpy as np
from PIL import Image
from utils import FDA_source_to_target_np
import scipy.misc
from keras.preprocessing.image import array_to_img


im_src = source_ffd[..., None]
im_trg = targ_ffd[..., None]


im_src = im_src.transpose((2, 0, 1))
im_trg = im_trg.transpose((2, 0, 1))

for i in np.linspace(0, 1, 20):

    src_in_trg = FDA_source_to_target_np(im_src, im_trg, L=i) # [0.18, 0.5]

    src_in_trg = src_in_trg.transpose((1, 2, 0))

    src_in_trg = scale_img(src_in_trg)

    fig, axs = plt.subplots(1, 3, figsize=(15, 15))
    plt.title(i)
    axs[0].imshow(source_ffd, cmap=plt.cm.gray_r)
    axs[1].imshow(targ_ffd, cmap=plt.cm.gray_r)
    axs[2].imshow(src_in_trg.squeeze(), cmap=plt.cm.gray_r)
